# %%
# %run 1-reference-attack.ipynb
verbose_reference_dp = True
# Out:
# Loading diabetes dataset

# %% [markdown]
# ## Defending against a reference attack

# %%
from diffprivlib.models import RandomForestClassifier as dp_RFC

def train_model_dp(X_train, y_train, seed=42):
    rfc = dp_RFC(
        n_estimators=80,
        max_depth=10,
        random_state=42,
        epsilon=1e0,
        bounds=(np.min(X_train, axis=0), np.max(X_train, axis=0)),
        classes=np.unique(y_train),
    )
    rfc.fit(X_train, y_train)
    return rfc

# %%
if verbose_reference_dp:
    target_model_dp = train_model_dp(X_train, y_train)
    plot_rfc_auroc(target_model_dp, X_test, y_test)

# %%
if verbose_reference_dp:
    plot_reference_attack(train_model_dp, X_train, y_train, X_test, y_test,20)
# Out:
#   0%|                                                                                       | 0/50 [00:00<?, ?it/s]/Users/ligasser/anaconda3/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#   2%|█▌                                                                             | 1/50 [00:13<10:39, 13.05s/it]/Users/ligasser/anaconda3/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#   4%|███▏                                                                           | 2/50 [00:26<10:27, 13.07s/it]/Users/ligasser/anaconda3/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2176: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# ...
